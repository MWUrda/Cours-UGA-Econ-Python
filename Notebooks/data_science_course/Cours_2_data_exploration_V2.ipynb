# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Setup

# %% [markdown]
# For the scope of this tutorial we are going to use AirBnb Scraped data for the city of Paris. The data is freely available at **Inside AirBnb**: http://insideairbnb.com/get-the-data.html.
#
# A description of all variables in all datasets is avaliable [here](https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=982310896).
#
# We are going to use 2 datasets:
#
# - listing dataset: contains listing-level information
# - pricing dataset: contains pricing data, over time

# %% [markdown]
# ## Importing Data

# %% [markdown]
# Pandas has a variety of function to import data
#
# - `pd.read_csv()`
# - `pd.read_html()`
# - `pd.read_parquet()`
#
# Importatly for our purpose, `pd.read_csv()` can directly import data from the web.

# %% [markdown]
# The first dataset that we are going to import is the dataset of Airbnb listings in Bordeaux. It contains listing-level information.

# %%
url_listings = "https://data.insideairbnb.com/france/nouvelle-aquitaine/bordeaux/2025-06-15/visualisations/listings.csv"
df_listings = pd.read_csv(url_listings)

# %% [markdown]
# The second dataset that we are going to use is the dataset of calendar prices. This time the dataset is compressed but we can use the `compression` option to import it directly.

# %%
url_prices = "https://data.insideairbnb.com/france/nouvelle-aquitaine/bordeaux/2025-06-15/data/calendar.csv.gz"
df_prices = pd.read_csv(url_prices, compression="gzip")

# %% [markdown]
# ## Inspecting Data

# %% [markdown]
# > Methods
# >
# >- `info()`
# >- `head()`
# >- `describe()`

# %% [markdown]
# The first way yo have a quick look at the data is the `info()` method. If called with the option `verbose=False`, it gives a quick overview of the dimensions of the data.

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12383 entries, 0 to 12382
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              12383 non-null  int64
#  1   name                            12383 non-null  object
#  2   host_id                         12383 non-null  int64
#  3   host_name                       12383 non-null  object
#  4   neighbourhood_group             12383 non-null  object
#  5   neighbourhood                   12383 non-null  object
#  6   latitude                        12383 non-null  float64
#  7   longitude                       12383 non-null  float64
#  8   room_type                       12383 non-null  object
#  9   price                           8345 non-null   float64
#  10  minimum_nights                  12383 non-null  int64
#  11  number_of_reviews               12383 non-null  int64
#  12  last_review                     10257 non-null  object
#  13  reviews_per_month               10257 non-null  float64
#  14  calculated_host_listings_count  12383 non-null  int64
#  15  availability_365                12383 non-null  int64
#  16  number_of_reviews_ltm           12383 non-null  int64
#  17  license                         4805 non-null   object
# dtypes: float64(4), int64(7), object(7)
# memory usage: 1.7+ MB

# %% [markdown]
# If we want to know how the data looks like, we can use the `head()` method. It prints the first 5 lines of the data by default.

# %%
df_listings.head()
# Out:
#        id                                               name  host_id  \
# 0  222887           Spectacular view, full air-con, elevator  1156398
# 1  247452                     Cosy apartment ,barbecue, pool   959918
# 2  317273       Luxury, spacious, patio, near public gardens  1156398
# 3  317658  Key to Bordeaux · fairytale view, 2 bd + elevator  1156398
# 4  333031      STUDIO BORDEAUX TRIANGLE D OR ***** Climatisé  1697156
#
#   host_name    neighbourhood_group                           neighbourhood  \
# 0   Suzanne               Bordeaux                            Bordeaux Sud
# 1    Krista  Saint-Mdard-en-Jalles                   Saint-Mdard-en-Jalles
# 2   Suzanne               Bordeaux  Chartrons - Grand Parc - Jardin Public
# 3   Suzanne               Bordeaux                 Centre ville (Bordeaux)
# 4    Antony               Bordeaux                 Centre ville (Bordeaux)
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0  44.836102  -0.566395  Entire home/apt  266.0               3
# 1  44.858900  -0.727350  Entire home/apt  115.0               3
# 2  44.847801  -0.581046  Entire home/apt  203.0               3
# 3  44.838799  -0.568870  Entire home/apt  222.0               3
# 4  44.842560  -0.577940  Entire home/apt  103.0               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                127  2025-06-22               0.77
# 1                 79  2025-04-03               0.49
# 2                 80  2025-04-29               0.60
# 3                161  2025-04-28               1.00
# 4                556  2025-06-09               3.45
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               4               248                     31
# 1                               1               147                      9
# 2                               4               273                     20
# 3                               4               269                     17
# 4                               2               353                     53
#
#          license
# 0  3306300031048
# 1            NaN
# 2  33063001366CB
# 3  33063001225CF
# 4  3306300055979

# %% [markdown]
# We can print a description of the data using `describe()`. If we have many variables, it's best to print it transposed using the `.T` attribute.

# %%
df_listings.describe().T[:5]
# Out:
#              count          mean           std            min           25%  \
# id         12383.0  5.339815e+17  5.518793e+17  222887.000000  2.774426e+07
# host_id    12383.0  1.600508e+08  1.785551e+08   30374.000000  2.937686e+07
# latitude   12383.0  4.484028e+01  3.101698e-02      44.750530  4.482420e+01
# longitude  12383.0 -5.881860e-01  4.622049e-02      -0.831114 -6.041521e-01
# price       8345.0  1.253258e+02  3.660109e+02      12.000000  5.200000e+01
#
#                     50%           75%           max
# id         5.833414e+17  1.076652e+18  1.442850e+18
# host_id    7.636601e+07  2.325568e+08  7.002933e+08
# latitude   4.483893e+01  4.485541e+01  4.501855e+01
# longitude -5.775376e-01 -5.649800e-01 -4.642800e-01
# price      7.900000e+01  1.300000e+02  1.000000e+04

# %% [markdown]
# You can select which variables to display using the `include` option. `include='all'` includes also categorical variables.

# %%
df_listings.describe(include='all').T[:5]
# Out:
#                        count unique          top  freq                  mean  \
# id                   12383.0    NaN          NaN   NaN  533981500596552192.0
# name                   12383  11759  Appartement    19                   NaN
# host_id              12383.0    NaN          NaN   NaN      160050802.918598
# host_name              12383   2674    Guillaume   156                   NaN
# neighbourhood_group    12383     28     Bordeaux  6817                   NaN
#
#                                       std       min         25%  \
# id                   551879327470255616.0  222887.0  27744263.5
# name                                  NaN       NaN         NaN
# host_id                   178555149.27013   30374.0  29376862.5
# host_name                             NaN       NaN         NaN
# neighbourhood_group                   NaN       NaN         NaN
#
#                                       50%                    75%  \
# id                   583341418005836928.0  1076652408833679360.0
# name                                  NaN                    NaN
# host_id                        76366007.0            232556765.5
# host_name                             NaN                    NaN
# neighbourhood_group                   NaN                    NaN
#
#                                        max
# id                   1442849858401247232.0
# name                                   NaN
# host_id                        700293334.0
# host_name                              NaN
# neighbourhood_group                    NaN

# %% [markdown]
# We can get the list of columns using the `.columns` attribute.

# %%
df_listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %% [markdown]
# We can get the index using the `.index` attribute,

# %%
df_listings.index
# Out:
# RangeIndex(start=0, stop=12383, step=1)

# %% [markdown]
# ## Data Selection

# %% [markdown]
# We can access single columns as if the DataFrame was a dictionary.

# %%
df_listings['price']
# Out:
# 0        266.0
# 1        115.0
# 2        203.0
# 3        222.0
# 4        103.0
#          ...
# 12378     65.0
# 12379    117.0
# 12380     63.0
# 12381     35.0
# 12382    147.0
# Name: price, Length: 12383, dtype: float64

# %% [markdown]
# We can select rows and columns by index, using the `.iloc` attribute.

# %%
df_listings.iloc[:7, 5:9]
# Out:
#                             neighbourhood   latitude  longitude  \
# 0                            Bordeaux Sud  44.836102  -0.566395
# 1                   Saint-Mdard-en-Jalles  44.858900  -0.727350
# 2  Chartrons - Grand Parc - Jardin Public  44.847801  -0.581046
# 3                 Centre ville (Bordeaux)  44.838799  -0.568870
# 4                 Centre ville (Bordeaux)  44.842560  -0.577940
# 5                                   Bgles  44.811490  -0.558250
# 6  Chartrons - Grand Parc - Jardin Public  44.854470  -0.582000
#
#          room_type
# 0  Entire home/apt
# 1  Entire home/apt
# 2  Entire home/apt
# 3  Entire home/apt
# 4  Entire home/apt
# 5  Entire home/apt
# 6     Private room

# %% [markdown]
# If we want to condition only on rows or columns, we have use `:` for the unrestricted dimesion, otherwise we get an error.

# %%
df_listings.iloc[:, 5:9].head()
# Out:
#                             neighbourhood   latitude  longitude  \
# 0                            Bordeaux Sud  44.836102  -0.566395
# 1                   Saint-Mdard-en-Jalles  44.858900  -0.727350
# 2  Chartrons - Grand Parc - Jardin Public  44.847801  -0.581046
# 3                 Centre ville (Bordeaux)  44.838799  -0.568870
# 4                 Centre ville (Bordeaux)  44.842560  -0.577940
#
#          room_type
# 0  Entire home/apt
# 1  Entire home/apt
# 2  Entire home/apt
# 3  Entire home/apt
# 4  Entire home/apt

# %% [markdown]
# Instead, the `.loc` attribute allows us to use row and column names.

# %%
df_listings.loc[:, ['neighbourhood', 'latitude', 'longitude']].head()
# Out:
#                             neighbourhood   latitude  longitude
# 0                            Bordeaux Sud  44.836102  -0.566395
# 1                   Saint-Mdard-en-Jalles  44.858900  -0.727350
# 2  Chartrons - Grand Parc - Jardin Public  44.847801  -0.581046
# 3                 Centre ville (Bordeaux)  44.838799  -0.568870
# 4                 Centre ville (Bordeaux)  44.842560  -0.577940

# %% [markdown]
# We can also select ranges.

# %%
df_listings.loc[:, 'neighbourhood':'room_type'].head()
# Out:
#                             neighbourhood   latitude  longitude  \
# 0                            Bordeaux Sud  44.836102  -0.566395
# 1                   Saint-Mdard-en-Jalles  44.858900  -0.727350
# 2  Chartrons - Grand Parc - Jardin Public  44.847801  -0.581046
# 3                 Centre ville (Bordeaux)  44.838799  -0.568870
# 4                 Centre ville (Bordeaux)  44.842560  -0.577940
#
#          room_type
# 0  Entire home/apt
# 1  Entire home/apt
# 2  Entire home/apt
# 3  Entire home/apt
# 4  Entire home/apt

# %% [markdown]
# There is an easy way to **select numerical columns**, the `.select_dtypes()` function.

# %%
df_listings.select_dtypes(include=['number']).head()
# Out:
#        id  host_id   latitude  longitude  price  minimum_nights  \
# 0  222887  1156398  44.836102  -0.566395  266.0               3
# 1  247452   959918  44.858900  -0.727350  115.0               3
# 2  317273  1156398  44.847801  -0.581046  203.0               3
# 3  317658  1156398  44.838799  -0.568870  222.0               3
# 4  333031  1697156  44.842560  -0.577940  103.0               1
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                127               0.77                               4
# 1                 79               0.49                               1
# 2                 80               0.60                               4
# 3                161               1.00                               4
# 4                556               3.45                               2
#
#    availability_365  number_of_reviews_ltm
# 0               248                     31
# 1               147                      9
# 2               273                     20
# 3               269                     17
# 4               353                     53

# %% [markdown]
# Other types include
#
# - `object` for strings
# - `bool` for booleans
# - `int` for integers
# - `float` for floats (numbers that are not integers)

# %% [markdown]
# We can also use logical operators to selet rows.

# %%
df_listings.loc[df_listings['number_of_reviews']>500, :].head()
# Out:
#          id                                           name   host_id  \
# 4    333031  STUDIO BORDEAUX TRIANGLE D OR ***** Climatisé   1697156
# 9    482102              Beautiful city house full comfort   2387430
# 53  1117474                   INCROYABLE T3 EN HYPERCENTRE  70229865
# 54  1136724  Spacious house, 4 guests with Garden & Garage   3774373
# 57  1172803                           PATIO STUDIO  CENTRE   1029070
#
#               host_name neighbourhood_group  \
# 4                Antony            Bordeaux
# 9              Frederic          Le Bouscat
# 53               Thomas            Bordeaux
# 54  Stéphane & Virginie            Bordeaux
# 57                Louis            Bordeaux
#
#                                 neighbourhood  latitude  longitude  \
# 4                     Centre ville (Bordeaux)  44.84256   -0.57794
# 9                                  Le Bouscat  44.85420   -0.59581
# 53                    Centre ville (Bordeaux)  44.83871   -0.56846
# 54  Saint Augustin - Tauzin - Alphonse Dupeux  44.82893   -0.58775
# 57                               Bordeaux Sud  44.83472   -0.57507
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 4   Entire home/apt  103.0               1                556  2025-06-09
# 9   Entire home/apt  224.0               2                503  2025-06-19
# 53  Entire home/apt  130.0               3                516  2025-06-11
# 54  Entire home/apt    NaN               2                581  2025-02-05
# 57  Entire home/apt   59.0               4                711  2025-06-13
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 4                3.45                               2               353
# 9                3.19                               1               307
# 53               3.50                              22               190
# 54               3.97                               2                 0
# 57               4.86                               5               104
#
#     number_of_reviews_ltm        license
# 4                      53  3306300055979
# 9                      34            NaN
# 53                     41  330630009852A
# 54                     15  33063003349C9
# 57                     25  330630002860D

# %% [markdown]
# We can use logical operations as well. But remember to use paranthesis.
#
# **Note**: the `and` and `or` expressions do not work in this setting. We have to use `&` and `|` instead.

# %%
df_listings.loc[(df_listings['number_of_reviews']>300) &
                (df_listings['reviews_per_month']>7), 
                :].head()
# Out:
#             id                                               name   host_id  \
# 394    6424164  Belle et grande chambre avec salle de bain privée  33338004
# 726    9591925     Chambre privée  chez l'habitant face à la gare  49645813
# 804   10890090  Chambre privée chez l'habitant gare  saintjean...  49645813
# 1104  12926326                 Charmante Maison à 5mn de Bordeaux  70937383
# 1116  12956742     Bright and independent room without vis-a-vis.  62154643
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 394     Thierry            Merignac         Arlac  44.82891   -0.63392
# 726      Julien            Bordeaux  Bordeaux Sud  44.82543   -0.55688
# 804      Julien            Bordeaux  Bordeaux Sud  44.82748   -0.55680
# 1104  Alexandre             Floirac       Floirac  44.83349   -0.52772
# 1116     Claude          Le Bouscat    Le Bouscat  44.86797   -0.58236
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 394      Private room   41.0               1                926  2025-06-12
# 726      Private room   47.0               1               1068  2025-06-25
# 804      Private room   50.0               1                862  2025-06-25
# 1104  Entire home/apt   46.0               1                893  2025-06-19
# 1116     Private room   35.0               1                829  2025-06-22
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 394                7.54                               2               208
# 726                9.16                               4               362
# 804                7.54                               4               363
# 1104               8.09                               4               269
# 1116               7.55                               2               344
#
#       number_of_reviews_ltm        license
# 394                      92            NaN
# 726                      93  330630000616c
# 804                      69  330630000616c
# 1104                     84            NaN
# 1116                     80            NaN

# %% [markdown]
# For a single column (i.e. a Series), we can get the unique values using the `unique()` function.

# %%
df_listings['neighbourhood'].unique()
# Out:
# array(['Bordeaux Sud', 'Saint-Mdard-en-Jalles',
#        'Chartrons - Grand Parc - Jardin Public',
#        'Centre ville (Bordeaux)', 'Bgles', 'Talence', 'Le Bouscat',
#        'Saint Augustin - Tauzin - Alphonse Dupeux', 'Caudran',
#        'Nansouty - Saint Gens', 'Magonty', 'Palmer-Gravires-Cavailles',
#        'Carbon-Blanc', 'La Glacire', 'France Alouette', 'Gradignan',
#        'Le Bourg', 'Eysines', 'Bouliac', 'Lormont', 'Saint-Aubin-de-Mdoc',
#        'Floirac', 'La Bastide', 'Verthamon', 'Chiquet-Fontaudin',
#        'Bordeaux Maritime', 'Bruges', "Villenave-d'Ornon", 'Les Eyquems',
#        'Bourran', 'Parempuyre', 'Gambetta-Mairie-Lissandre', 'Capeyron',
#        'Arlac', 'Chemin Long', 'Ambars-et-Lagrave', 'Blanquefort',
#        'Bassens', 'Le Haillan', 'Le Monteil', 'Saige', 'Beaudsert',
#        'Sardine', 'Le Taillan-Mdoc', 'Centre ville (Merignac)',
#        'Martignas-sur-Jalle', 'Cap de Bos', 'Casino', 'Beutre',
#        '3M-Bourgailh', 'Plaisance-Loret-Maregue', 'Nos',
#        'Artigues-Prs-Bordeaux', 'Saint-Louis-de-Montferrand',
#        'Brivazac-Candau', 'La Paillre-Compostelle',
#        'Arago-La Chataigneraie', 'Toctoucau', 'Le Vallon-Les Echoppes',
#        'Le Burck', 'Ambs', 'Saint-Vincent-de-Paul'], dtype=object)

# %% [markdown]
# For multiple columns, we can use the `drop_duplicates` function.

# %%
df_listings[['neighbourhood', 'room_type']].drop_duplicates()
# Out:
#                                 neighbourhood        room_type
# 0                                Bordeaux Sud  Entire home/apt
# 1                       Saint-Mdard-en-Jalles  Entire home/apt
# 2      Chartrons - Grand Parc - Jardin Public  Entire home/apt
# 3                     Centre ville (Bordeaux)  Entire home/apt
# 5                                       Bgles  Entire home/apt
# ...                                       ...              ...
# 11042                                Le Bourg      Shared room
# 11207                                 Caudran      Shared room
# 11209                                 Bourran      Shared room
# 11275                                   Bgles      Shared room
# 12241                             Blanquefort      Shared room
#
# [144 rows x 2 columns]

# %% [markdown]
# ## Aggregation and Pivot Tables

# %% [markdown]
# We can compute statistics by group using `.groupby()`.

# %%
df_listings.groupby('neighbourhood')[['price', 'reviews_per_month']].mean()
# Out:
#                              price  reviews_per_month
# neighbourhood
# 3M-Bourgailh             43.527769           1.271122
# Ambars-et-Lagrave       122.678057           1.465372
# Ambs                     68.858551           0.851952
# Arago-La Chataigneraie   63.807201           1.287130
# Arlac                    67.683729           1.403024
# ...                            ...                ...
# Sardine                  68.684359           1.749963
# Talence                  74.721414           1.579673
# Toctoucau               152.552261           1.832516
# Verthamon                70.956368           1.879508
# Villenave-d'Ornon        79.483183           1.853547
#
# [62 rows x 2 columns]

# %% [markdown]
# If you want to perform more than one function, maybe on different columns, you can use `.aggregate()` which can be shortened to `.agg()`. It takes as argument a dictionary with variables as keys and lists of functions as values.

# %%
df_listings.groupby('neighbourhood').agg({"price": ["mean"],
                                          "minimum_nights": ["min", np.max]}).reset_index()
# Out:
#              neighbourhood       price minimum_nights
#                                   mean            min amax
# 0             3M-Bourgailh   68.000000              1    7
# 1        Ambars-et-Lagrave  124.272727              1   12
# 2                     Ambs   59.500000              1    3
# 3   Arago-La Chataigneraie   74.581818              1    7
# 4                    Arlac   93.851351              1  200
# ..                     ...         ...            ...  ...
# 57                 Sardine   79.727273              1   40
# 58                 Talence   84.757437              1  364
# 59               Toctoucau  187.230769              1   14
# 60               Verthamon   88.384615              1   90
# 61       Villenave-d'Ornon   79.621891              1  300
#
# [62 rows x 4 columns]

# %% [markdown]
# The problem with this syntax is that it generates a hierarchical structure for variable names, which might not be so easy to work with. In the example above, to access the mean price, you have to use `df.price["min"]`.
#
# To perform variable naming and aggregation and the same time, you can ise the following syntax: `agg(output_var = ("input_var", function))`.

# %%
df_listings.groupby('neighbourhood').agg(mean_reviews=("price", "mean"),
                                         min_price=("price", "min"),
                                         max_price=("price", np.max)).reset_index()
# Out:
#              neighbourhood  mean_reviews  min_price  max_price
# 0             3M-Bourgailh      0.850000       22.0      150.0
# 1        Ambars-et-Lagrave      1.097692       29.0      622.0
# 2                     Ambs      0.727273       23.0      290.0
# 3   Arago-La Chataigneraie      1.077302       26.0      342.0
# 4                    Arlac      1.080115       20.0      394.0
# ..                     ...           ...        ...        ...
# 57                 Sardine      1.305000       28.0      300.0
# 58                 Talence      1.208582       16.0      760.0
# 59               Toctoucau      1.184000       30.0      636.0
# 60               Verthamon      1.456786       30.0      280.0
# 61       Villenave-d'Ornon      1.425573       18.0      765.0
#
# [62 rows x 4 columns]

# %% [markdown]
# We can make pivot tables with the `.pivot_table()` function. It takes the folling arguments:
#
# - `index`: rows
# - `columns`: columns
# - `values`: values
# - `aggfunc`: aggregation function

# %%
df_listings.pivot_table(index='neighbourhood', columns='room_type', values='price', aggfunc='mean')
# Out:
# room_type               Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood
# 3M-Bourgailh                  96.800000         NaN     39.200000          NaN
# Ambars-et-Lagrave            148.761905         NaN     45.153846          NaN
# Ambs                         113.250000         NaN     38.000000          NaN
# Arago-La Chataigneraie        88.268293         NaN     34.500000          NaN
# Arlac                        105.475410         NaN     39.307692          NaN
# ...                                 ...         ...           ...          ...
# Sardine                      100.785714         NaN     42.875000          NaN
# Talence                       98.724551       130.0     38.578431          NaN
# Toctoucau                    219.400000         NaN     80.000000          NaN
# Verthamon                    105.473684         NaN     42.000000          NaN
# Villenave-d'Ornon             94.772414         NaN     40.392857          NaN
#
# [62 rows x 4 columns]
