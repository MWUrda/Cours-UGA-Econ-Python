# %% [markdown]
# # Problème: calculer un équilibre de Walras dans une économie avec de nombreux agents
#
# - Les questions suivantes mobilisent les cours 1-3. Le cours 3 en particulier pour tout ce qui concerne les nombres aléatoires, et les graphiques interactifs.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Tâches

# %% [markdown]
# ## 1. Nombres aléatoires

# %% [markdown]
# Remplacer les lignes manquantes afin d'obtenir la résultat affiché

# %%
import numpy as np
np.random.seed(1986)
# LIGNE MANQUANTE
for i in range(3):
    # LIGNE MANQUANTE
    for j in range(2):
        x = np.random.uniform()
        print(f'({i},{j}): x = {x:.3f}')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# (0,0): x = 0.569
# (0,1): x = 0.077
# (1,0): x = 0.569
# (1,1): x = 0.077
# (2,0): x = 0.569
# (2,1): x = 0.077

# %% [markdown]
# ## 2. Calculer une espérance et une variance

# %% [markdown]
# Obtenir une variance et une variance selon:
#
# $$
# \mathbb{E}[g(x)] \approx \frac{1}{N}\sum_{i=1}^{N} g(x_i)
# $$
# $$
# \mathbb{VAR}[g(x)] \approx \frac{1}{N}\sum_{i=1}^{N} \left( g(x_i) - \frac{1}{N}\sum_{i=1}^{N} g(x_i) \right)^2
# $$
#
# où $ x_i \sim \mathcal{N}(0,\sigma) $ et
#
# $$
# g(x,\omega)=\begin{cases}
# x & \text{if }x\in[-\omega,\omega]\\
# -\omega & \text{if }x<-\omega\\
# \omega & \text{if }x>\omega
# \end{cases}
# $$

# %%
sigma = 3.14
omega = 2
N = 10000
np.random.seed(1986)
# Écrivez votre code ci-dessous pour obtenir le résultat affiché
# Out:
# mean = -0.00264, var = 2.69804

# %% [markdown]
# ## 3. Histogramme interactif

# %% [markdown]
# ### 3.1
# Dans le code suivant complétez les lignes manquantes pour avoir le résultat affiché

# %%
# a. imports
import ipywidgets as widgets
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# b. graph


def fitting_normal(X, mu_guess, sigma_guess):

    # i. distribution normale à partir de valeurs "candidates" "mu_guess" et "sigma_guess" pour moyenne et variance.
    F = norm(loc=mu_guess, scale=sigma_guess)

    # ii. valeurs pour x
    # LIGNE MANQUANTE, x_low = # valeur de x où la distribution est 0.001
    # LIGNE MANQUANTE, x_high = # valeur de x où la distribution est 0.999
    x = np.linspace(x_low, x_high, 100)

    # iii. graph
    fig = plt.figure(dpi=100)
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(x, F.pdf(x), lw=2)
    ax.hist(X, bins=100, density=True, histtype='stepfilled')
    ax.set_ylim([0, 0.5])
    ax.set_xlim([-6, 6])


# c. paramètres
mu_true = 2
sigma_true = 1
mu_guess = 1
sigma_guess = 2

# d. graph
X = np.random.normal(loc=mu_true, scale=sigma_true, size=10**6)

# e. figure
try:
    fitting_normal(X,mu_guess,sigma_guess)
#LIGNE MANQUANTE
    print('failed')

# %% [markdown]
# ### 3.2 Graph Interactif
#
# Faîtes un graph interactif ayant le résultat suivant avec curseur pour sigma et mu

# %%
# Votre code
# Out:
# interactive(children=(FloatSlider(value=1.0, description='$ \\mu $', max=5.0, min=0.1, step=0.05), FloatSlider…
# <function __main__.fitting_normal(X, mu_guess, sigma_guess)>
